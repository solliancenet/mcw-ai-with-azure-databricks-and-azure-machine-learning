# %% [markdown]
# # Azure Notebook Environment Setup
# Before running any of the notebooks in this lab, be sure you have run this notebook within your active Azure Notebooks environment.

# %%
# !pip install --upgrade pip
# !pip install --upgrade azureml-sdk[notebooks,explain,automl,contrib]
# !pip install scikit-learn==0.20.3
# !pip install -U scikit-image
# Out:
# Requirement already up-to-date: pip in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (19.1.1)
# Requirement already up-to-date: azureml-sdk[automl,contrib,explain,notebooks] in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (1.0.43)
# ...
# Requirement already up-to-date: scikit-image in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (0.15.0)
# ...
